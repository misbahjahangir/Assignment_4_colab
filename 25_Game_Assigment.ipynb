# %% [markdown]
# <a href="https://colab.research.google.com/github/misbahjahangir/Assignment_4_colab/blob/main/25_Game_Assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Welcome message
print("Welcome to the Kylie Ying Python Tutorial!")

# Get user's name
name = input("What's your name? ")

# Get user's favorite color
color = input("What's your favorite color? ")

# Print a message using f-strings
print(f"Hi {name}! {color} is a beautiful color.")

# Get user's age
age = input("How old are you? ")

# Use string concatenation
print("Wow, " + name + "! You're " + age + " years old.")

# Final message with both techniques
print(f"Nice to meet you, {name}. Have a colorful day with {color} around you!")

# %%
import random

# Function to start the game
def guess_the_number():
    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 10.")

    # Generate a random number between 1 and 10
    secret_number = random.randint(1, 10)

    # Ask user to guess until they get it right
    while True:
        guess = input("Take a guess: ")

        # Check if input is a number
        if not guess.isdigit():
            print("Please enter a valid number.")
            continue

        guess = int(guess)

        if guess < secret_number:
            print("Too low! Try again.")
        elif guess > secret_number:
            print("Too high! Try again.")
        else:
            print(f"Congratulations! You guessed it right. The number was {secret_number}.")
            break

# Run the game
guess_the_number()

# %%
import random

def computer_guess():
    print("Welcome to the Reverse Guessing Game!")
    print("Think of a number between 1 and 100, and I'll try to guess it.")
    print("After each guess, tell me if it's (H)igh, (L)ow, or (C)orrect.")

    low = 1
    high = 100
    feedback = ''

    while feedback != 'c':
        if low != high:
            guess = random.randint(low, high)
        else:
            guess = low  # only one possible number left

        print(f"My guess is: {guess}")
        feedback = input("Is it (H)igh, (L)ow, or (C)orrect? ").lower()

        if feedback == 'h':
            high = guess - 1
        elif feedback == 'l':
            low = guess + 1
        elif feedback == 'c':
            print(f"Yay! I guessed your number: {guess}")
        else:
            print("Please enter H, L, or C only.")

# Start the game
computer_guess()

# %%
import random

def play_game():
    print("Welcome to Rock, Paper, Scissors!")
    options = ['rock', 'paper', 'scissors']

    user_choice = input("Choose rock, paper, or scissors: ").lower()
    computer_choice = random.choice(options)

    print(f"\nYou chose: {user_choice}")
    print(f"Computer chose: {computer_choice}\n")

    if user_choice == computer_choice:
        print("It's a tie!")
    elif user_choice == 'rock':
        if computer_choice == 'scissors':
            print("You win! Rock crushes scissors.")
        else:
            print("You lose! Paper covers rock.")
    elif user_choice == 'paper':
        if computer_choice == 'rock':
            print("You win! Paper covers rock.")
        else:
            print("You lose! Scissors cut paper.")
    elif user_choice == 'scissors':
        if computer_choice == 'paper':
            print("You win! Scissors cut paper.")
        else:
            print("You lose! Rock crushes scissors.")
    else:
        print("Invalid input. Please choose rock, paper, or scissors.")

# Run the game
play_game()

# %%
import random
import string

def run_quiz():
    # Questions stored in a dictionary
    questions = {
        "What is the capital of France?": ["a) Berlin", "b) Paris", "c) Rome", "d) Madrid"],
        "Which language is primarily used for web development?": ["a) Python", "b) Java", "c) HTML", "d) C++"],
        "What is 5 * 6?": ["a) 30", "b) 11", "c) 56", "d) 20"],
        "Which one is a Python data type?": ["a) chair", "b) float", "c) jump", "d) fast"]
    }

    # Correct answers for each question (key: correct option letter)
    answers = {
        "What is the capital of France?": "b",
        "Which language is primarily used for web development?": "c",
        "What is 5 * 6?": "a",
        "Which one is a Python data type?": "b"
    }

    # Shuffle questions
    question_list = list(questions.keys())
    random.shuffle(question_list)

    score = 0
    print("Welcome to the Quiz Game!\n")

    for q in question_list:
        print(q)
        for option in questions[q]:
            print(option)

        user_answer = input("Enter your answer (a/b/c/d): ").lower().strip()

        # Check if input is valid using string module
        if user_answer in string.ascii_lowercase[:4]:
            if user_answer == answers[q]:
                print("✅ Correct!\n")
                score += 1
            else:
                print(f"❌ Wrong! The correct answer was '{answers[q]}'\n")
        else:
            print("Invalid choice. Please choose a, b, c, or d.\n")

    print(f"Quiz Over! You got {score}/{len(questions)} questions correct.")

# Start the quiz
run_quiz()

# %%
import time

# User se seconds input lena
seconds = int(input("Enter the time in seconds: "))

# Countdown loop
while seconds > 0:
    mins = seconds // 60
    secs = seconds % 60
    timer = f'{mins:02d}:{secs:02d}'
    print(timer, end='\r')  # '\r' se line overwrite hoti hai
    time.sleep(1)  # 1 second wait
    seconds -= 1

print("Time's up!")

# %%
import random
import string

# User input
num_passwords = int(input("How many passwords do you want to generate? "))
password_length = int(input("What should be the length of each password? "))

# Character set (you can customize this)
characters = string.ascii_letters + string.digits + string.punctuation

print("\nGenerated Passwords:")

# Password generation loop
for i in range(num_passwords):
    password = ''.join(random.choice(characters) for _ in range(password_length))
    print(f"{i+1}: {password}")

# %%
import qrcode

# User se data lena
data = input("Enter the data/text you want to convert into a QR Code: ")

# QR code banayein
qr = qrcode.make(data)

# Save karein
qr.save("my_qr.png")

print("QR Code successfully generated and saved as 'my_qr.png'")


import cv2

# Load QR image
image = cv2.imread("my_qr.png")

# QRCode detector
detector = cv2.QRCodeDetector()

data, bbox, _ = detector.detectAndDecode(image)

if data:
    print("Decoded Data from QR Code:")
    print(data)
else:
    print("QR Code not detected or unreadable.")

# %%
import time

# Display the board
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

# Check for win
def check_winner(board, player):
    # Rows, columns and diagonals
    for row in board:
        if all(cell == player for cell in row):
            return True

    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True

    if all(board[i][i] == player for i in range(3)) or \
       all(board[i][2 - i] == player for i in range(3)):
        return True

    return False

# Check for draw
def is_draw(board):
    return all(cell != " " for row in board for cell in row)

# Main game
def play_game():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    print("Welcome to Tic-Tac-Toe!\n")
    print_board(board)

    while True:
        print(f"\nPlayer {current_player}'s turn.")
        try:
            row = int(input("Enter row (0-2): "))
            col = int(input("Enter col (0-2): "))

            if board[row][col] != " ":
                print("That spot is already taken. Try again.")
                continue

            board[row][col] = current_player
            print_board(board)

            if check_winner(board, current_player):
                print(f"\nPlayer {current_player} wins!")
                break

            if is_draw(board):
                print("\nIt's a draw!")
                break

            # Switch player
            current_player = "O" if current_player == "X" else "X"

            time.sleep(1)  # Add a short delay between turns
        except (ValueError, IndexError):
            print("Invalid input. Please enter row and column as numbers from 0 to 2.")

# Run the game
play_game()

# %%
import math

# Display the board
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

# Check for winner
def check_winner(board):
    # Rows, columns and diagonals
    for row in board:
        if row[0] == row[1] == row[2] != " ":
            return row[0]

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] != " ":
            return board[0][col]

    if board[0][0] == board[1][1] == board[2][2] != " ":
        return board[0][0]

    if board[0][2] == board[1][1] == board[2][0] != " ":
        return board[0][2]

    return None

# Check for draw
def is_draw(board):
    return all(cell != " " for row in board for cell in row)

# Minimax algorithm
def minimax(board, depth, is_maximizing):
    winner = check_winner(board)
    if winner == "O":
        return 1
    elif winner == "X":
        return -1
    elif is_draw(board):
        return 0

    if is_maximizing:
        best_score = -math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == " ":
                    board[i][j] = "O"
                    score = minimax(board, depth + 1, False)
                    board[i][j] = " "
                    best_score = max(score, best_score)
        return best_score
    else:
        best_score = math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == " ":
                    board[i][j] = "X"
                    score = minimax(board, depth + 1, True)
                    board[i][j] = " "
                    best_score = min(score, best_score)
        return best_score

# Computer's move
def computer_move(board):
    best_score = -math.inf
    move = None
    for i in range(3):
        for j in range(3):
            if board[i][j] == " ":
                board[i][j] = "O"
                score = minimax(board, 0, False)
                board[i][j] = " "
                if score > best_score:
                    best_score = score
                    move = (i, j)
    if move:
        board[move[0]][move[1]] = "O"

# Main game loop
def play_game():
    board = [[" " for _ in range(3)] for _ in range(3)]
    print("Welcome to Unbeatable Tic-Tac-Toe!")
    print("You are X. Computer is O.\n")
    print_board(board)

    while True:
        # Player move
        while True:
            try:
                row = int(input("Enter your row (0-2): "))
                col = int(input("Enter your col (0-2): "))
                if board[row][col] == " ":
                    board[row][col] = "X"
                    break
                else:
                    print("Cell already taken. Try again.")
            except (ValueError, IndexError):
                print("Invalid input. Enter numbers 0, 1, or 2.")

        print_board(board)

        if check_winner(board) == "X":
            print("You win! 🎉")
            break
        elif is_draw(board):
            print("It's a draw.")
            break

        print("Computer is thinking...")
        computer_move(board)
        print_board(board)

        if check_winner(board) == "O":
            print("Computer wins! 🤖")
            break
        elif is_draw(board):
            print("It's a draw.")
            break

# Run the game
play_game()

# %%
def binary_search(arr, target):
    left = 0
    right = len(arr) - 1

    while left <= right:
        mid = (left + right) // 2  # middle index nikalo
        if arr[mid] == target:
            return mid  # target mil gaya, uska index return karo
        elif arr[mid] < target:
            left = mid + 1  # target right half mein ho sakta hai
        else:
            right = mid - 1  # target left half mein ho sakta hai

    return -1  # agar target nahi mila
# Sorted list
numbers = [2, 4, 6, 10, 15, 20, 25, 30]

# Search for 15
result = binary_search(numbers, 15)

if result != -1:
    print(f"Element found at index {result}")
else:
    print("Element not found")

# %%
import random

class Cell:
    def __init__(self):
        self.mine = False
        self.revealed = False
        self.flagged = False
        self.adjacent_mines = 0

    def __str__(self):
        if self.flagged:
            return "F"
        if not self.revealed:
            return "-"
        if self.mine:
            return "*"
        return str(self.adjacent_mines) if self.adjacent_mines > 0 else " "

class Minesweeper:
    def __init__(self, rows, cols, mines):
        self.rows = rows
        self.cols = cols
        self.mines = mines
        self.board = [[Cell() for _ in range(cols)] for _ in range(rows)]
        self.plant_mines()
        self.calculate_adjacency()
        self.revealed_cells = 0
        self.total_cells = rows * cols - mines
        self.game_over = False

    def plant_mines(self):
        planted = 0
        while planted < self.mines:
            r = random.randint(0, self.rows - 1)
            c = random.randint(0, self.cols - 1)
            if not self.board[r][c].mine:
                self.board[r][c].mine = True
                planted += 1

    def calculate_adjacency(self):
        for r in range(self.rows):
            for c in range(self.cols):
                if self.board[r][c].mine:
                    continue
                self.board[r][c].adjacent_mines = self.count_adjacent_mines(r, c)

    def count_adjacent_mines(self, row, col):
        count = 0
        for dr in [-1, 0, 1]:
            for dc in [-1, 0, 1]:
                r, c = row + dr, col + dc
                if 0 <= r < self.rows and 0 <= c < self.cols:
                    if self.board[r][c].mine:
                        count += 1
        return count

    def reveal(self, row, col):
        if not (0 <= row < self.rows and 0 <= col < self.cols):
            return
        cell = self.board[row][col]
        if cell.revealed or cell.flagged:
            return
        cell.revealed = True
        if cell.mine:
            self.game_over = True
            return
        self.revealed_cells += 1
        if cell.adjacent_mines == 0:
            for dr in [-1, 0, 1]:
                for dc in [-1, 0, 1]:
                    if dr != 0 or dc != 0:
                        self.reveal(row + dr, col + dc)

    def print_board(self, reveal_all=False):
        print("   " + " ".join(str(i) for i in range(self.cols)))
        for i, row in enumerate(self.board):
            line = f"{i:2} " + " ".join(
                str(cell) if not reveal_all else
                "*" if cell.mine else
                str(cell.adjacent_mines) if cell.adjacent_mines > 0 else " "
                for cell in row
            )
            print(line)

    def play(self):
        while not self.game_over and self.revealed_cells < self.total_cells:
            self.print_board()
            try:
                r, c = map(int, input("Enter row and column (e.g., 1 2): ").split())
                self.reveal(r, c)
            except Exception as e:
                print("Invalid input. Please enter two numbers separated by a space.")

        self.print_board(reveal_all=True)
        if self.game_over:
            print("💥 Boom! You hit a mine. Game over.")
        else:
            print("🎉 Congratulations! You cleared the board!")

# Start the game
if __name__ == "__main__":
    game = Minesweeper(rows=8, cols=8, mines=10)
    game.play()

# %%
def print_board(board):
    for i in range(9):
        row = ""
        for j in range(9):
            if j % 3 == 0 and j != 0:
                row += " | "
            row += str(board[i][j]) if board[i][j] != 0 else "."
            row += " "
        print(row)
        if (i + 1) % 3 == 0 and i != 8:
            print("-" * 21)

def find_empty(board):
    for i in range(9):
        for j in range(9):
            if board[i][j] == 0:
                return (i, j)
    return None

def is_valid(board, num, pos):
    row, col = pos

    # Check row
    for i in range(9):
        if board[row][i] == num and col != i:
            return False

    # Check column
    for i in range(9):
        if board[i][col] == num and row != i:
            return False

    # Check 3x3 box
    box_x = col // 3
    box_y = row // 3

    for i in range(box_y * 3, box_y * 3 + 3):
        for j in range(box_x * 3, box_x * 3 + 3):
            if board[i][j] == num and (i, j) != pos:
                return False

    return True

def solve(board):
    find = find_empty(board)
    if not find:
        return True  # Solved!
    row, col = find

    for num in range(1, 10):
        if is_valid(board, num, (row, col)):
            board[row][col] = num

            if solve(board):
                return True

            board[row][col] = 0  # Backtrack

    return False
if __name__ == "__main__":
    sudoku_board = [
        [5, 3, 0, 0, 7, 0, 0, 0, 0],
        [6, 0, 0, 1, 9, 5, 0, 0, 0],
        [0, 9, 8, 0, 0, 0, 0, 6, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 3],
        [4, 0, 0, 8, 0, 3, 0, 0, 1],
        [7, 0, 0, 0, 2, 0, 0, 0, 6],
        [0, 6, 0, 0, 0, 0, 2, 8, 0],
        [0, 0, 0, 4, 1, 9, 0, 0, 5],
        [0, 0, 0, 0, 8, 0, 0, 7, 9]
    ]

    print("🔢 Sudoku Puzzle:")
    print_board(sudoku_board)
    print("\n🧠 Solving...\n")

    if solve(sudoku_board):
        print("✅ Solved Sudoku:")
        print_board(sudoku_board)
    else:
        print("❌ No solution exists.")

# %%
from PIL import Image, ImageEnhance, ImageFilter

def apply_filters(image_path, brightness_factor, contrast_factor, blur_radius):
    # Open the image
    image = Image.open(image_path)

    # Apply brightness
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(brightness_factor)

    # Apply contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(contrast_factor)

    # Apply blur
    if blur_radius > 0:
        image = image.filter(ImageFilter.GaussianBlur(blur_radius))

    return image

def main():
    print("🖼️ Image Filter Tool")
    image_path = input("Enter the image file path (e.g., photo.jpg): ")

    try:
        brightness = float(input("Enter brightness factor (e.g., 1.2 for +20%): "))
        contrast = float(input("Enter contrast factor (e.g., 0.8 for -20%): "))
        blur = float(input("Enter blur radius (e.g., 2.0 for light blur): "))

        result = apply_filters(image_path, brightness, contrast, blur)

        output_path = "filtered_image.jpg"
        result.save(output_path)
        print(f"✅ Image saved as {output_path}")

        result.show()  # Open the image in default viewer

    except Exception as e:
        print("❌ Error:", e)

if __name__ == "__main__":
    main()

# %%
from PIL import Image, ImageEnhance, ImageFilter

def apply_filters(image_path, brightness_factor, contrast_factor, blur_radius):
    # Open the image
    image = Image.open(image_path)

    # Apply brightness
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(brightness_factor)

    # Apply contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(contrast_factor)

    # Apply blur
    if blur_radius > 0:
        image = image.filter(ImageFilter.GaussianBlur(blur_radius))

    return image

def main():
    print("🖼️ Image Filter Tool")
    image_path = input("Enter the image file path (e.g., photo.jpg): ")

    try:
        brightness = float(input("Enter brightness factor (e.g., 1.2 for +20%): "))
        contrast = float(input("Enter contrast factor (e.g., 0.8 for -20%): "))
        blur = float(input("Enter blur radius (e.g., 2.0 for light blur): "))

        result = apply_filters(image_path, brightness, contrast, blur)

        output_path = "filtered_image.jpg"
        result.save(output_path)
        print(f"✅ Image saved as {output_path}")

        result.show()  # Open the image in default viewer

    except Exception as e:
        print("❌ Error:", e)

if __name__ == "__main__":
    main()

# %%
import turtle
import os

# Screen setup
win = turtle.Screen()
win.title("🏓 Classic Pong by Turtle")
win.bgcolor("black")
win.setup(width=800, height=600)
win.tracer(0)  # Turn off automatic screen updates

# Score
score_a = 0
score_b = 0

# Paddle A
paddle_a = turtle.Turtle()
paddle_a.speed(0)  # Fastest animation speed
paddle_a.shape("square")
paddle_a.color("white")
paddle_a.shapesize(stretch_wid=5, stretch_len=1)  # Taller paddle
paddle_a.penup()
paddle_a.goto(-350, 0)

# Paddle B
paddle_b = turtle.Turtle()
paddle_b.speed(0)
paddle_b.shape("square")
paddle_b.color("white")
paddle_b.shapesize(stretch_wid=5, stretch_len=1)
paddle_b.penup()
paddle_b.goto(350, 0)

# Ball
ball = turtle.Turtle()
ball.speed(0)
ball.shape("circle")
ball.color("white")
ball.penup()
ball.goto(0, 0)
ball.dx = 0.25  # Ball movement in x
ball.dy = 0.25  # Ball movement in y

# Score Display
pen = turtle.Turtle()
pen.speed(0)
pen.color("white")
pen.penup()
pen.hideturtle()
pen.goto(0, 260)
pen.write("Player A: 0  |  Player B: 0", align="center", font=("Courier", 20, "normal"))

# Paddle movement functions
def paddle_a_up():
    y = paddle_a.ycor()
    if y < 250:
        paddle_a.sety(y + 20)

def paddle_a_down():
    y = paddle_a.ycor()
    if y > -240:
        paddle_a.sety(y - 20)

def paddle_b_up():
    y = paddle_b.ycor()
    if y < 250:
        paddle_b.sety(y + 20)

def paddle_b_down():
    y = paddle_b.ycor()
    if y > -240:
        paddle_b.sety(y - 20)

# Keyboard bindings
win.listen()
win.onkeypress(paddle_a_up, "w")
win.onkeypress(paddle_a_down, "s")
win.onkeypress(paddle_b_up, "Up")
win.onkeypress(paddle_b_down, "Down")

# Game loop
while True:
    win.update()

    # Move the ball
    ball.setx(ball.xcor() + ball.dx)
    ball.sety(ball.ycor() + ball.dy)

    # Top & Bottom boundary collision
    if ball.ycor() > 290:
        ball.sety(290)
        ball.dy *= -1
        os.system("afplay bounce.wav&")  # For macOS — replace with "aplay" for Linux or remove for Windows

    if ball.ycor() < -290:
        ball.sety(-290)
        ball.dy *= -1
        os.system("afplay bounce.wav&")

    # Right wall
    if ball.xcor() > 390:
        ball.goto(0, 0)
        ball.dx *= -1
        score_a += 1
        pen.clear()
        pen.write(f"Player A: {score_a}  |  Player B: {score_b}", align="center", font=("Courier", 20, "normal"))

    # Left wall
    if ball.xcor() < -390:
        ball.goto(0, 0)
        ball.dx *= -1
        score_b += 1
        pen.clear()
        pen.write(f"Player A: {score_a}  |  Player B: {score_b}", align="center", font=("Courier", 20, "normal"))

    # Paddle collisions
    if (340 < ball.xcor() < 350) and (paddle_b.ycor() - 50 < ball.ycor() < paddle_b.ycor() + 50):
        ball.setx(340)
        ball.dx *= -1

    if (-350 < ball.xcor() < -340) and (paddle_a.ycor() - 50 < ball.ycor() < paddle_a.ycor() + 50):
        ball.setx(-340)
        ball.dx *= -1

# %%
import pygame
import random
import sys

# Initialize Pygame
pygame.init()

# Constants
WIDTH, HEIGHT = 600, 400
CELL_SIZE = 20
FPS = 10

# Colors
WHITE = (255, 255, 255)
GREEN = (0, 255, 0)
RED = (200, 0, 0)
BLACK = (0, 0, 0)

# Directions
UP = (0, -1)
DOWN = (0, 1)
LEFT = (-1, 0)
RIGHT = (1, 0)


class Snake:
    def __init__(self):
        self.body = [(5, 5), (4, 5), (3, 5)]
        self.direction = RIGHT
        self.grow_flag = False

    def move(self):
        head_x, head_y = self.body[0]
        dx, dy = self.direction
        new_head = (head_x + dx, head_y + dy)

        self.body.insert(0, new_head)

        if self.grow_flag:
            self.grow_flag = False
        else:
            self.body.pop()

    def grow(self):
        self.grow_flag = True

    def change_direction(self, new_direction):
        if (new_direction[0] * -1, new_direction[1] * -1) != self.direction:
            self.direction = new_direction

    def check_collision(self):
        head = self.body[0]
        return (
            head in self.body[1:] or
            head[0] < 0 or head[0] >= WIDTH // CELL_SIZE or
            head[1] < 0 or head[1] >= HEIGHT // CELL_SIZE
        )


class Food:
    def __init__(self):
        self.position = self.random_position()

    def random_position(self):
        return (
            random.randint(0, (WIDTH - CELL_SIZE) // CELL_SIZE),
            random.randint(0, (HEIGHT - CELL_SIZE) // CELL_SIZE)
        )

    def draw(self, screen):
        x, y = self.position
        rect = pygame.Rect(x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE)
        pygame.draw.rect(screen, RED, rect)


class Game:
    def __init__(self):
        self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
        pygame.display.set_caption("Snake Game")
        self.clock = pygame.time.Clock()
        self.snake = Snake()
        self.food = Food()
        self.running = True

    def draw_grid(self):
        for x in range(0, WIDTH, CELL_SIZE):
            pygame.draw.line(self.screen, WHITE, (x, 0), (x, HEIGHT))
        for y in range(0, HEIGHT, CELL_SIZE):
            pygame.draw.line(self.screen, WHITE, (0, y), (WIDTH, y))

    def draw_snake(self):
        for segment in self.snake.body:
            x, y = segment
            rect = pygame.Rect(x * CELL_SIZE, y * CELL_SIZE, CELL_SIZE, CELL_SIZE)
            pygame.draw.rect(self.screen, GREEN, rect)

    def check_food_collision(self):
        if self.snake.body[0] == self.food.position:
            self.snake.grow()
            self.food = Food()

    def game_over(self):
        font = pygame.font.SysFont(None, 48)
        text = font.render("Game Over!", True, RED)
        self.screen.blit(text, (WIDTH // 2 - 100, HEIGHT // 2 - 30))
        pygame.display.flip()
        pygame.time.wait(2000)
        self.running = False

    def run(self):
        while self.running:
            self.clock.tick(FPS)
            self.handle_events()
            self.snake.move()
            self.check_food_collision()

            if self.snake.check_collision():
                self.game_over()

            self.screen.fill(BLACK)
            self.draw_grid()
            self.draw_snake()
            self.food.draw(self.screen)
            pygame.display.flip()

        pygame.quit()
        sys.exit()

    def handle_events(self):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                self.running = False
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_UP:
                    self.snake.change_direction(UP)
                elif event.key == pygame.K_DOWN:
                    self.snake.change_direction(DOWN)
                elif event.key == pygame.K_LEFT:
                    self.snake.change_direction(LEFT)
                elif event.key == pygame.K_RIGHT:
                    self.snake.change_direction(RIGHT)


if __name__ == "__main__":
    game = Game()
    game.run()

# %%
import numpy as np
import pygame
import sys
import math

# Constants
ROW_COUNT = 6
COLUMN_COUNT = 7
SQUARESIZE = 100
RADIUS = int(SQUARESIZE/2 - 5)
width = COLUMN_COUNT * SQUARESIZE
height = (ROW_COUNT+1) * SQUARESIZE
size = (width, height)

# Colors
BLUE = (0, 0, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
YELLOW = (255, 255, 0)

# Pygame init
pygame.init()
font = pygame.font.SysFont("monospace", 75)
screen = pygame.display.set_mode(size)


def create_board():
    return np.zeros((ROW_COUNT, COLUMN_COUNT))


def drop_piece(board, row, col, piece):
    board[row][col] = piece


def is_valid_location(board, col):
    return board[ROW_COUNT-1][col] == 0


def get_next_open_row(board, col):
    for r in range(ROW_COUNT):
        if board[r][col] == 0:
            return r


def print_board(board):
    print(np.flip(board, 0))


def winning_move(board, piece):
    # Check horizontal
    for c in range(COLUMN_COUNT-3):
        for r in range(ROW_COUNT):
            if all([board[r][c+i] == piece for i in range(4)]):
                return True

    # Check vertical
    for c in range(COLUMN_COUNT):
        for r in range(ROW_COUNT-3):
            if all([board[r+i][c] == piece for i in range(4)]):
                return True

    # Check positive diagonal
    for c in range(COLUMN_COUNT-3):
        for r in range(ROW_COUNT-3):
            if all([board[r+i][c+i] == piece for i in range(4)]):
                return True

    # Check negative diagonal
    for c in range(COLUMN_COUNT-3):
        for r in range(3, ROW_COUNT):
            if all([board[r-i][c+i] == piece for i in range(4)]):
                return True

    return False


def draw_board(board):
    for c in range(COLUMN_COUNT):
        for r in range(ROW_COUNT):
            pygame.draw.rect(screen, BLUE,
                             (c*SQUARESIZE, r*SQUARESIZE+SQUARESIZE, SQUARESIZE, SQUARESIZE))
            pygame.draw.circle(screen, BLACK,
                               (int(c*SQUARESIZE+SQUARESIZE/2), int(r*SQUARESIZE+SQUARESIZE+SQUARESIZE/2)), RADIUS)

    for c in range(COLUMN_COUNT):
        for r in range(ROW_COUNT):
            if board[r][c] == 1:
                pygame.draw.circle(screen, RED,
                                   (int(c*SQUARESIZE+SQUARESIZE/2), height - int(r*SQUARESIZE+SQUARESIZE/2)), RADIUS)
            elif board[r][c] == 2:
                pygame.draw.circle(screen, YELLOW,
                                   (int(c*SQUARESIZE+SQUARESIZE/2), height - int(r*SQUARESIZE+SQUARESIZE/2)), RADIUS)

    pygame.display.update()


# Main Game Loop
board = create_board()
game_over = False
turn = 0

draw_board(board)
pygame.display.update()

while not game_over:

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            sys.exit()

        if event.type == pygame.MOUSEMOTION:
            pygame.draw.rect(screen, BLACK, (0, 0, width, SQUARESIZE))
            posx = event.pos[0]
            if turn == 0:
                pygame.draw.circle(screen, RED, (posx, int(SQUARESIZE/2)), RADIUS)
            else:
                pygame.draw.circle(screen, YELLOW, (posx, int(SQUARESIZE/2)), RADIUS)
        pygame.display.update()

        if event.type == pygame.MOUSEBUTTONDOWN:
            pygame.draw.rect(screen, BLACK, (0, 0, width, SQUARESIZE))

            # Ask for Player 1 Input
            if turn == 0:
                posx = event.pos[0]
                col = int(math.floor(posx/SQUARESIZE))

                if is_valid_location(board, col):
                    row = get_next_open_row(board, col)
                    drop_piece(board, row, col, 1)

                    if winning_move(board, 1):
                        label = font.render("Player 1 wins!", True, RED)
                        screen.blit(label, (40, 10))
                        game_over = True

            # Ask for Player 2 Input
            else:
                posx = event.pos[0]
                col = int(math.floor(posx/SQUARESIZE))

                if is_valid_location(board, col):
                    row = get_next_open_row(board, col)
                    drop_piece(board, row, col, 2)

                    if winning_move(board, 2):
                        label = font.render("Player 2 wins!", True, YELLOW)
                        screen.blit(label, (40, 10))
                        game_over = True

            print_board(board)
            draw_board(board)

            turn += 1
            turn %= 2

            if game_over:
                pygame.time.wait(3000)

# %%
import pygame
import sys

# Initialize Pygame
pygame.init()

# Recreate the Classic Tetris Game using Pygame.
# In this project, you will learn how to build the classic Tetris game from scratch.
# It uses the Pygame library and is great for beginner developers
# looking to take their programming skills to the next level.

# Set up display
SCREEN_WIDTH = 300
SCREEN_HEIGHT = 600
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption("Tetris Game")

# Set up clock
clock = pygame.time.Clock()
FPS = 60

# Main game loop
running = True
while running:
    screen.fill((0, 0, 0))  # Fill screen with black

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # Update display
    pygame.display.flip()
    clock.tick(FPS)

# Quit Pygame
pygame.quit()
sys.exit()

# %%
import socket
import threading

# Server setup
HOST = '127.0.0.1'  # Use your public IP for global multiplayer
PORT = 5555

server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server.bind((HOST, PORT))
server.listen()

print(f"[SERVER STARTED] Listening on {HOST}:{PORT}")

clients = []

# Handle each client
def handle_client(conn, addr):
    print(f"[NEW CONNECTION] {addr} connected.")
    while True:
        try:
            data = conn.recv(1024).decode()
            if not data:
                break
            print(f"[{addr}] {data}")
            # Broadcast to all other clients
            for client in clients:
                if client != conn:
                    client.sendall(data.encode())
        except:
            break

    print(f"[DISCONNECTED] {addr}")
    clients.remove(conn)
    conn.close()

# Accept new clients
while True:
    conn, addr = server.accept()
    clients.append(conn)
    thread = threading.Thread(target=handle_client, args=(conn, addr))
    thread.start()

# %%
import requests
from bs4 import BeautifulSoup

def get_profile_image(url):
    """
    GitHub user profile page se profile image link extract karta hai.

    Args:
        url (str): https://github.com/misbahjahangir.

    Returns:
        str or None: Profile image link mil jaaye to, otherwise None.
    """
    # Headers include a user agent to mimic a browser
    headers = {"User-Agent": "Mozilla/5.0"}

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Throws an error for non-200 status
    except requests.RequestException as e:
        print("Error fetching URL:", e)
        return None

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # GitHub profile image usually contained in an <img> tag with class 'avatar-user'
    # Note: GitHub may update its DOM structure. You might need to adjust the selector.
    profile_img = soup.find('img', class_="avatar-user")
    if profile_img and profile_img.get("src"):
        return profile_img["src"]
    return None

if __name__ == "__main__":
    # Ask user for GitHub profile link
    user_url = input("https://github.com/misbahjahangir: ").strip()

    # Extract and display the profile image link
    profile_image_link = get_profile_image(user_url)
    if profile_image_link:
        print("Profile image link:", profile_image_link)
    else:
        print("Could not extract the profile image link from the provided URL.")

# %%
import os

# Step 1: Ask user to input the folder path
folder_path = input("Enter the full path to the folder you want to rename files in:\n")

# Step 2: Define the rule for renaming files
def rename_rule(original_name):
    """
    Custom renaming rule.
    Modify this function to change how file names should be renamed.
    """
    # Example: Add "renamed_" before the file name
    return "renamed_" + original_name

# Step 3: Go through each file and rename it
def rename_files(folder):
    try:
        # Loop through all files in the folder
        for filename in os.listdir(folder):
            old_path = os.path.join(folder, filename)

            # Skip directories
            if os.path.isdir(old_path):
                continue

            # Split name and extension
            name, ext = os.path.splitext(filename)

            # Apply renaming rule
            new_name = rename_rule(name) + ext
            new_path = os.path.join(folder, new_name)

            # Rename the file
            os.rename(old_path, new_path)
            print(f"Renamed: {filename} ➝ {new_name}")

        print("\nAll files renamed successfully!")
    except Exception as e:
        print(f"Error: {e}")

# Step 4: Run the function
rename_files(folder_path)

# %%
import requests

# Step 1: Enter your OpenWeatherMap API Key here
API_KEY = 'YOUR_API_KEY_HERE'

# Step 2: Take city name from user
city = input("Enter the city name: ")

# Step 3: Create API URL
url = f"https://www.accuweather.com/en/pk/karachi/261158/weather-forecast/261158"

# Step 4: Make API request
response = requests.get(url)

# Step 5: Check response
if response.status_code == 200:
    data = response.json()

    main = data['main']
    weather = data['weather'][0]

    temp = main['temp']
    feels_like = main['feels_like']
    humidity = main['humidity']
    description = weather['description']

    print(f"\n🌍 Weather in {city.capitalize()}:\n")
    print(f"Temperature: {temp}°C")
    print(f"Feels like: {feels_like}°C")
    print(f"Humidity: {humidity}%")
    print(f"Description: {description.capitalize()}")
else:
    print("\n❌ City not found. Please check the name and try again.")

# %%
import os
import discord
from discord.ext import commands

# Bot ka prefix (e.g. !hello)
bot = commands.Bot(command_prefix="!", intents=discord.Intents.default())

# Bot jab online aaye to ye chalega
@bot.event
async def on_ready():
    print(f'Bot is ready. Logged in as {bot.user}')

@bot.command()
async def hello(ctx):
    await ctx.send(f'Hello {ctx.author.name}!')

# Token ko Replit ke secret se le rahe hain
TOKEN = os.environ['DISCORD_BOT_TOKEN']

# Bot ko start karna
bot.run(TOKEN)

# %%
import pygame
import random
import math

# Initialize Pygame
pygame.init()

# Create the screen
screen = pygame.display.set_mode((800, 600))

# Title and Icon
pygame.display.set_caption("Space Invaders")
icon = pygame.image.load('spaceship.png')  # Replace with your icon image
pygame.display.set_icon(icon)

# Background
background = pygame.image.load('background.png')  # Replace with your background image

# Player
playerImg = pygame.image.load('player.png')  # Replace with your player image
playerX = 370
playerY = 480
playerX_change = 0

# Enemy
enemyImg = []
enemyX = []
enemyY = []
enemyX_change = []
enemyY_change = []
num_of_enemies = 6

for i in range(num_of_enemies):
    enemyImg.append(pygame.image.load('enemy.png'))  # Replace with your enemy image
    enemyX.append(random.randint(0, 736))
    enemyY.append(random.randint(50, 150))
    enemyX_change.append(4)
    enemyY_change.append(40)

# Bullet
bulletImg = pygame.image.load('bullet.png')  # Replace with your bullet image
bulletX = 0
bulletY = 480
bulletX_change = 0
bulletY_change = 10
bullet_state = "ready"  # "ready" = can shoot, "fire" = bullet is moving

# Score
score_value = 0
font = pygame.font.Font(None, 36)

textX = 10
textY = 10

def show_score(x, y):
    score = font.render("Score : " + str(score_value), True, (255, 255, 255))
    screen.blit(score, (x, y))

# Player function
def player(x, y):
    screen.blit(playerImg, (x, y))

# Enemy function
def enemy(x, y, i):
    screen.blit(enemyImg[i], (x, y))

# Bullet function
def fire_bullet(x, y):
    global bullet_state
    bullet_state = "fire"
    screen.blit(bulletImg, (x + 16, y + 10))

# Collision detection
def is_collision(enemyX, enemyY, bulletX, bulletY):
    distance = math.sqrt((math.pow(enemyX - bulletX, 2)) + (math.pow(enemyY - bulletY, 2)))
    return distance < 27

# Game loop
running = True
while running:
    screen.fill((0, 0, 0))  # Background color
    screen.blit(background, (0, 0))

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        # Key press
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                playerX_change = -5
            if event.key == pygame.K_RIGHT:
                playerX_change = 5
            if event.key == pygame.K_SPACE:
                if bullet_state == "ready":
                    bulletX = playerX
                    fire_bullet(bulletX, bulletY)

        if event.type == pygame.KEYUP:
            if event.key in [pygame.K_LEFT, pygame.K_RIGHT]:
                playerX_change = 0

    playerX += playerX_change
    playerX = max(0, min(playerX, 736))  # Boundary

    # Enemy movement
    for i in range(num_of_enemies):

        # Game over condition
        if enemyY[i] > 440:
            for j in range(num_of_enemies):
                enemyY[j] = 2000
            break

        enemyX[i] += enemyX_change[i]
        if enemyX[i] <= 0 or enemyX[i] >= 736:
            enemyX_change[i] *= -1
            enemyY[i] += enemyY_change[i]

        # Collision
        collision = is_collision(enemyX[i], enemyY[i], bulletX, bulletY)
        if collision:
            bulletY = 480
            bullet_state = "ready"
            score_value += 1
            enemyX[i] = random.randint(0, 736)
            enemyY[i] = random.randint(50, 150)

        enemy(enemyX[i], enemyY[i], i)

    # Bullet movement
    if bullet_state == "fire":
        fire_bullet(bulletX, bulletY)
        bulletY -= bulletY_change

    if bulletY <= 0:
        bulletY = 480
        bullet_state = "ready"

    player(playerX, playerY)
    show_score(textX, textY)

    pygame.display.update()
